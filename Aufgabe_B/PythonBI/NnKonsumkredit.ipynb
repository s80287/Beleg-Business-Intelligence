# %%
import pandas as pd
import numpy as np

from numpy import ndarray
from util.base import Data
from util.visualizerNN import NetVisualizer

from lincoln.activations import Sigmoid, Tanh, ReLU, Linear
from lincoln.train import Trainer
from lincoln.optimizers import SGD, SGDMomentum
from lincoln.network import NeuralNetwork
from lincoln.layers import Dense
from lincoln.losses import SoftmaxCrossEntropy, MeanSquaredError
from lincoln.np_utils import to_2d

# %% [markdown]
# ## <span style="color: blue"> **Einlesen, Analysieren und Vorverarbeiten der Daten** </span>

# %% [markdown]
# ### DataFrame aus der csv-Datei einlesen

# %%
csvFile="data/Konsumkredit.csv"
df = pd.read_csv(csvFile)
df
# Out:
#      Geschlecht Familienstand  Kinder         Beruf Wohneigentum  Einkommen  \
# 0             W             V       1     ungelernt            N       2514
# 1             M             V       0     ungelernt            N       2285
# 2             M             V       1     angelernt            N       3468
# 3             W             V       0     unbekannt            N       2172
# 4             M             W       1  Facharbeiter            J       2101
# ...         ...           ...     ...           ...          ...        ...
# 2419          M             V       1     unbekannt            N       3241
# 2420          W             V       1  Facharbeiter            N       3362
# 2421          M             V       1  Facharbeiter            N       3618
# 2422          W             V       2  Facharbeiter            N       3169
# 2423          M             V       1  Facharbeiter            N       3604
#
#      Ersparnisse kreditwuerdig
# 0              N             N
# 1              J             N
# 2              N             N
# 3              N             N
# 4              J             N
# ...          ...           ...
# 2419           J             J
# 2420           J             J
# 2421           J             J
# 2422           J             J
# 2423           J             J
#
# [2424 rows x 8 columns]

# %% [markdown]
# ### Zielvariable (label) festlegen

# %%
classLabel = 'N_kreditwuerdig'

# %% [markdown]
# ### Vorverarbeitung
# - binäre Werte: eine neue Spalte => 1,0
# - nominale Werte: je Werte eine neue Spalte => [1,...,0] ... [0,...,1]
# - numerische Werte: eine neue Spalte mit Normierung zwischen Minwert und Maxwert  =>  0...1

# %%
# binäre Werte
column = 'kreditwuerdig'
df[f'N_{column}'] = np.where(df[column] == 'J', 1, 0)

column = 'Geschlecht'
df[f'N_{column}'] = np.where(df[column] == 'M', 1, 0)

# nominale Werte
column = 'Familienstand'
for value in df[column].unique():
    df[f'N_{column}{value}'] = np.where(df[column] == value, 1, 0)

# numerische Werte x1 und x2: je eine neue Spalte (N_x1 und N_x2) mit normierten Werten zwischen 0 und 1   
column = 'Kinder'
df[f'N_{column}'] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())

# nominal
column = 'Beruf'
for value in df[column].unique():
    df[f'N_{column}{value}'] = np.where(df[column] == value, 1, 0)

# binär
column = 'Wohneigentum'
df[f'N_{column}'] = np.where(df[column] == 'J', 1, 0)

# numerisch
column = 'Einkommen'
df[f'N_{column}'] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())

# binär
column = 'Ersparnisse'
df[f'N_{column}'] = np.where(df[column] == 'J', 1, 0)

# %% [markdown]
# # <span style="color: blue"> **Initialisieren der Daten für die Modellerstellung** </span>

# %% [markdown]
# ### Berechnung initialisieren und dabei Split in Trainungs-, Validierungs- und Testdatenmenge durchführen

# %%
listOfAttributes = []
data = Data(df = df)
data.initialize(listOfAttributes = listOfAttributes, classLabel = classLabel, trainProportion=0.65, valProportion=0.15)

# %% [markdown]
# ### Trainingsdaten

# %%
mask = df['_split'] == 'train'
df[mask]
# Out:
#      Geschlecht Familienstand  Kinder         Beruf Wohneigentum  Einkommen  \
# 1             M             V       0     ungelernt            N       2285
# 4             M             W       1  Facharbeiter            J       2101
# 7             M             V       2  Facharbeiter            J       2538
# 8             W             W       0  Facharbeiter            N       2818
# 9             W             V       2     angelernt            N       2762
# ...         ...           ...     ...           ...          ...        ...
# 2417          M             V       1        Lehrer            N       3707
# 2418          M             W       1     angelernt            N       3696
# 2419          M             V       1     unbekannt            N       3241
# 2420          W             V       1  Facharbeiter            N       3362
# 2423          M             V       1  Facharbeiter            N       3604
#
#      Ersparnisse kreditwuerdig  N_kreditwuerdig  N_Geschlecht  ...  \
# 1              J             N                0             1  ...
# 4              J             N                0             1  ...
# 7              J             N                0             1  ...
# 8              N             N                0             0  ...
# 9              N             N                0             0  ...
# ...          ...           ...              ...           ...  ...
# 2417           J             J                1             1  ...
# 2418           J             J                1             1  ...
# 2419           J             J                1             1  ...
# 2420           J             J                1             0  ...
# 2423           J             J                1             1  ...
#
#       N_Berufangelernt  N_Berufunbekannt  N_BerufFacharbeiter  \
# 1                    0                 0                    0
# 4                    0                 0                    1
# 7                    0                 0                    1
# 8                    0                 0                    1
# 9                    1                 0                    0
# ...                ...               ...                  ...
# 2417                 0                 0                    0
# 2418                 1                 0                    0
# 2419                 0                 1                    0
# 2420                 0                 0                    1
# 2423                 0                 0                    1
#
#       N_BerufBuerokraft  N_BerufManager  N_BerufLehrer  N_Wohneigentum  \
# 1                     0               0              0               0
# 4                     0               0              0               1
# 7                     0               0              0               1
# 8                     0               0              0               0
# 9                     0               0              0               0
# ...                 ...             ...            ...             ...
# 2417                  0               0              1               0
# 2418                  0               0              0               0
# 2419                  0               0              0               0
# 2420                  0               0              0               0
# 2423                  0               0              0               0
#
#       N_Einkommen  N_Ersparnisse  _split
# 1        0.042707              1   train
# 4        0.016600              1   train
# 7        0.078604              1   train
# 8        0.118331              0   train
# 9        0.110386              0   train
# ...           ...            ...     ...
# 2417     0.244467              1   train
# 2418     0.242906              1   train
# 2419     0.178348              1   train
# 2420     0.195516              1   train
# 2423     0.229852              1   train
#
# [1575 rows x 25 columns]

# %% [markdown]
# ### Testdaten

# %%
mask = df['_split'] == 'test'
df[mask]
# Out:
#      Geschlecht Familienstand  Kinder         Beruf Wohneigentum  Einkommen  \
# 3             W             V       0     unbekannt            N       2172
# 5             M             V       1     angelernt            J       2634
# 10            W             V       0     ungelernt            N       2583
# 12            M             W       1     ungelernt            N       2076
# 15            W             V       2     unbekannt            J       2432
# ...         ...           ...     ...           ...          ...        ...
# 2395          W             L       1  Facharbeiter            N       3418
# 2397          W             V       1     unbekannt            N       5669
# 2403          M             V       2       Manager            N       3521
# 2406          W             V       1        Lehrer            N       8860
# 2421          M             V       1  Facharbeiter            N       3618
#
#      Ersparnisse kreditwuerdig  N_kreditwuerdig  N_Geschlecht  ...  \
# 3              N             N                0             0  ...
# 5              J             N                0             1  ...
# 10             N             N                0             0  ...
# 12             J             N                0             1  ...
# 15             N             N                0             0  ...
# ...          ...           ...              ...           ...  ...
# 2395           J             J                1             0  ...
# 2397           J             J                1             0  ...
# 2403           J             J                1             1  ...
# 2406           J             J                1             0  ...
# 2421           J             J                1             1  ...
#
#       N_Berufangelernt  N_Berufunbekannt  N_BerufFacharbeiter  \
# 3                    0                 1                    0
# 5                    1                 0                    0
# 10                   0                 0                    0
# 12                   0                 0                    0
# 15                   0                 1                    0
# ...                ...               ...                  ...
# 2395                 0                 0                    1
# 2397                 0                 1                    0
# 2403                 0                 0                    0
# 2406                 0                 0                    0
# 2421                 0                 0                    1
#
#       N_BerufBuerokraft  N_BerufManager  N_BerufLehrer  N_Wohneigentum  \
# 3                     0               0              0               0
# 5                     0               0              0               1
# 10                    0               0              0               0
# 12                    0               0              0               0
# 15                    0               0              0               1
# ...                 ...             ...            ...             ...
# 2395                  0               0              0               0
# 2397                  0               0              0               0
# 2403                  0               1              0               0
# 2406                  0               0              1               0
# 2421                  0               0              0               0
#
#       N_Einkommen  N_Ersparnisse  _split
# 3        0.026674              0    test
# 5        0.092225              1    test
# 10       0.084989              0    test
# 12       0.013053              1    test
# 15       0.063564              0    test
# ...           ...            ...     ...
# 2395     0.203462              1    test
# 2397     0.522843              1    test
# 2403     0.218076              1    test
# 2406     0.975596              1    test
# 2421     0.231839              1    test
#
# [486 rows x 25 columns]

# %% [markdown]
# ### Validierungsdaten

# %%
mask = df['_split'] == 'val'
df[mask]
# Out:
#      Geschlecht Familienstand  Kinder         Beruf Wohneigentum  Einkommen  \
# 0             W             V       1     ungelernt            N       2514
# 2             M             V       1     angelernt            N       3468
# 6             M             V       0     unbekannt            N       2402
# 18            W             V       1       Manager            N       3945
# 19            W             V       1     ungelernt            N       2375
# ...         ...           ...     ...           ...          ...        ...
# 2404          M             V       2        Lehrer            N       7655
# 2405          M             V       2        Lehrer            J       8236
# 2413          M             V       2       Manager            N       5196
# 2414          M             L       1  Facharbeiter            N       5723
# 2422          W             V       2  Facharbeiter            N       3169
#
#      Ersparnisse kreditwuerdig  N_kreditwuerdig  N_Geschlecht  ...  \
# 0              N             N                0             0  ...
# 2              N             N                0             1  ...
# 6              J             N                0             1  ...
# 18             N             N                0             0  ...
# 19             N             N                0             0  ...
# ...          ...           ...              ...           ...  ...
# 2404           J             J                1             1  ...
# 2405           J             J                1             1  ...
# 2413           J             J                1             1  ...
# 2414           J             J                1             1  ...
# 2422           J             J                1             0  ...
#
#       N_Berufangelernt  N_Berufunbekannt  N_BerufFacharbeiter  \
# 0                    0                 0                    0
# 2                    1                 0                    0
# 6                    0                 1                    0
# 18                   0                 0                    0
# 19                   0                 0                    0
# ...                ...               ...                  ...
# 2404                 0                 0                    0
# 2405                 0                 0                    0
# 2413                 0                 0                    0
# 2414                 0                 0                    1
# 2422                 0                 0                    1
#
#       N_BerufBuerokraft  N_BerufManager  N_BerufLehrer  N_Wohneigentum  \
# 0                     0               0              0               0
# 2                     0               0              0               0
# 6                     0               0              0               0
# 18                    0               1              0               0
# 19                    0               0              0               0
# ...                 ...             ...            ...             ...
# 2404                  0               0              1               0
# 2405                  0               0              1               1
# 2413                  0               1              0               0
# 2414                  0               0              0               0
# 2422                  0               0              0               0
#
#       N_Einkommen  N_Ersparnisse  _split
# 0        0.075199              0     val
# 2        0.210556              0     val
# 6        0.059308              1     val
# 18       0.278235              0     val
# 19       0.055477              0     val
# ...           ...            ...     ...
# 2404     0.804625              1     val
# 2405     0.887060              1     val
# 2413     0.455732              1     val
# 2414     0.530505              1     val
# 2422     0.168133              1     val
#
# [363 rows x 25 columns]

# %% [markdown]
# ### Zusammenfassung des Split-Ergebnis

# %%
dfSplit = data.splitCheck()
dfSplit
# Out:
#                    Anzahl Datensätze  Anteil an Gesamt  Anzahl '0'  \
# Gesamt                          2424          1.000000        1290
# Trainingsdaten                  1575          0.649752         838
# Validierungsdaten                363          0.149752         193
# Testdaten                        486          0.200495         259
#
#                    Anteil '0'  Anzahl '1'  Anteil '1'
# Gesamt               0.532178        1134    0.467822
# Trainingsdaten       0.532063         737    0.467937
# Validierungsdaten    0.531680         170    0.468320
# Testdaten            0.532922         227    0.467078

# %% [markdown]
# ### Liste der normierten (!) Predictorvariablen (features) festlegen

# %%
listOfAttributes = ['N_Geschlecht', 'N_FamilienstandV', 
'N_FamilienstandW', 'N_FamilienstandL',
'N_Kinder', 'N_Berufungelernt', 'N_Berufangelernt', 
'N_Berufunbekannt', 'N_BerufFacharbeiter', 'N_BerufBuerokraft',
'N_BerufManager', 'N_BerufLehrer', 'N_Wohneigentum', 'N_Einkommen', 
'N_Ersparnisse']

# %% [markdown]
# ### ndArrays der Trainings-, Validierungs- und Testdaten erzeugen

# %%
trainAttributes = data.Df[listOfAttributes].loc[data.Df['_split'] == 'train'].to_numpy()
trainLabel = data.Df[classLabel].loc[data.Df['_split'] == 'train'].to_numpy()
valAttributes = data.Df[listOfAttributes].loc[data.Df['_split'] == 'val'].to_numpy()
valLabel = data.Df[classLabel].loc[data.Df['_split'] == 'val'].to_numpy()
testAttributes = data.Df[listOfAttributes].loc[data.Df['_split'] == 'test'].to_numpy()
testLabel = data.Df[classLabel].loc[data.Df['_split'] == 'test'].to_numpy()
testIndizes = data.Df.loc[data.Df['_split'] == 'test'].index.to_numpy()

# %% [markdown]
# ### 2D-Array der Zielvariablen (label)

# %%
trainLabel, valLabel, testLabel = to_2d(trainLabel), to_2d(valLabel), to_2d(testLabel)

# %% [markdown]
# # <span style="color: blue"> **Anlegen, Trainieren, Testen und Visualisieren des Neuronales Netzes** </span>

# %% [markdown]
# ### Anlegen des Netzes mit einem verdeckten Schicht

# %%
# Definition von Netzstruktur, Aktivierungsfunktionen und Verlustfunktion
model = NeuralNetwork(
        layers=[
                # hidden layer
                Dense(neurons=20,
                     activation=Sigmoid()),
                # output layer
                Dense(neurons=1,
                    activation=Sigmoid())
                ],
        loss=MeanSquaredError()
        )

# %% [markdown]
# ### Optimierungsverfahren

# %%
optimierer = SGDMomentum(lr=0.1)
#optimierer = SGD(lr= 0.1)

# %% [markdown]
# ### Training

# %%
trainer = Trainer(net=model, optim=optimierer)
trainer.fit(trainAttributes, trainLabel, valAttributes, valLabel,
                epochs=2000,
                eval_every=100,
                seed= 12345,
                batch_size= 20)
# Out:
# Validation loss after 100 epochs is 0.103
# Validation loss after 200 epochs is 0.093
# Validation loss after 300 epochs is 0.081
# Validation loss after 400 epochs is 0.079
#
# Loss increased after epoch 500, final loss was 0.079,
# using the model from epoch 400

# %% [markdown]
# ### Anwendung des Modells (des trainierten Netz) auf die Testdaten

# %%
# Loss der Anwendung
modellResult = trainer.net.forward(testAttributes)
loss = trainer.net.loss.forward(modellResult, testLabel)
loss
# Out:
# 0.07267157054134459

# %% [markdown]
# ### Ausgabe des Ergebnis der Modellanwendung

# %%
# flatten() erzeugt einen 1D-Array
resultOfModel = pd.Series(modellResult.flatten(), index = testIndizes)
real  = pd.Series(testLabel.flatten(), index = testIndizes)

# pd.concat liefert pd.DataFrame
dataframeOfResult = pd.concat([data.Df[classLabel].loc[data.Df['_split'] == 'test'],\
                real, resultOfModel], axis = 1)
dataframeOfResult.columns = [classLabel, 'Real', 'Modell_exakt'] 

# Ergebnis der Modellanwendung mittels Toleranz auf die Label 0 und 1 runden
toleranz = 0.25
conditionlist = [
    (dataframeOfResult['Modell_exakt'] >= 0-toleranz) & (dataframeOfResult['Modell_exakt'] <= 0+toleranz),
    (dataframeOfResult['Modell_exakt'] >= 1-toleranz) & (dataframeOfResult['Modell_exakt'] <= 1+toleranz)]
choicelist = [0, 1]   
dataframeOfResult['Modell'] = np.select(conditionlist, choicelist, default='unbestimmt')

dataframeOfResult
# Out:
#       N_kreditwuerdig  Real  Modell_exakt      Modell
# 3                   0     0  6.016973e-08           0
# 5                   0     0  7.187931e-06           0
# 10                  0     0  8.863093e-10           0
# 12                  0     0  7.977436e-05           0
# 15                  0     0  5.712635e-08           0
# ...               ...   ...           ...         ...
# 2395                1     1  9.435992e-01           1
# 2397                1     1  9.999989e-01           1
# 2403                1     1  4.396695e-01  unbestimmt
# 2406                1     1  1.000000e+00           1
# 2421                1     1  8.222732e-01           1
#
# [486 rows x 4 columns]

# %% [markdown]
# ### Ausgabe des Tests als Kreuztabelle

# %%
crossTable = pd.crosstab(dataframeOfResult['Modell'],
                             dataframeOfResult['Real'],
                             margins= True, margins_name='Summe')    
crossTable
# Out:
# Real          0    1  Summe
# Modell
# 0           223   10    233
# 1            17  204    221
# unbestimmt   19   13     32
# Summe       259  227    486

# %% [markdown]
# ### Ausgabe des Netzstruktur als Grafik

# %%
vs = NetVisualizer()
dot = vs.DrawNet(net = model, listOfInput = listOfAttributes, listOfOutput = [classLabel], nodesep = 0.1, ranksep= 0.3, showWeights = False)
dot

# %% [markdown]
# # <span style="color: blue"> **Neuronales Netz mit zwei verdeckten Schichten** </span>

# %% [markdown]
# ### Anlegen des Netzes

# %%
# Definition von Netzstruktur, Aktivierungsfunktionen und Verlustfunktion
model = NeuralNetwork(
        layers=[
                # hidden layer 1
                Dense(neurons=4,
                     activation=Sigmoid()),
                # hidden layer 2
                Dense(neurons=2,
                     activation=Sigmoid()),                
                # output layer
                Dense(neurons=1,
                    activation=Sigmoid())
                ],
        loss=MeanSquaredError()
        )

# %% [markdown]
# ### Optimierungsverfahren

# %%
optimierer = SGDMomentum(lr=0.1)
#optimierer = SGD(lr= 0.1)

# %% [markdown]
# ### Training

# %%
trainer = Trainer(net=model, optim=optimierer)
trainer.fit(trainAttributes, trainLabel, valAttributes, valLabel,
                epochs=4000,
                eval_every=100,
                seed= 12345,
                batch_size= 20)
# Out:
# Validation loss after 100 epochs is 0.091
# Validation loss after 200 epochs is 0.082
# Validation loss after 300 epochs is 0.080
# Validation loss after 400 epochs is 0.080
#
# Loss increased after epoch 500, final loss was 0.080,
# using the model from epoch 400

# %% [markdown]
# ### Anwendung des Modells auf die Testdaten

# %%
# Loss der Anwendung
modellResult = trainer.net.forward(testAttributes)
loss = trainer.net.loss.forward(modellResult, testLabel)
loss
# Out:
# 0.08851697021998123

# %% [markdown]
# ### Ausgabe des Ergebnis der Modellanwendung

# %%
# flatten() erzeugt einen 1D-Array
resultOfModel = pd.Series(modellResult.flatten(), index = testIndizes)
real  = pd.Series(testLabel.flatten(), index = testIndizes)

# pd.concat liefert pd.DataFrame
dataframeOfResult = pd.concat([data.Df[classLabel].loc[data.Df['_split'] == 'test'],\
                real, resultOfModel], axis = 1)
dataframeOfResult.columns = [classLabel, 'Real', 'Modell_exakt'] 

# Ergebnis der Modellanwendung mittels Toleranz auf die Label 0 und 1 runden
toleranz = 0.25
conditionlist = [
    (dataframeOfResult['Modell_exakt'] >= 0-toleranz) & (dataframeOfResult['Modell_exakt'] <= 0+toleranz),
    (dataframeOfResult['Modell_exakt'] >= 1-toleranz) & (dataframeOfResult['Modell_exakt'] <= 1+toleranz)]
choicelist = [0, 1]   
dataframeOfResult['Modell'] = np.select(conditionlist, choicelist, default='unbestimmt')

dataframeOfResult
# Out:
#       N_kreditwuerdig  Real  Modell_exakt Modell
# 3                   0     0      0.041560      0
# 5                   0     0      0.041515      0
# 10                  0     0      0.041930      0
# 12                  0     0      0.042034      0
# 15                  0     0      0.040478      0
# ...               ...   ...           ...    ...
# 2395                1     1      0.940005      1
# 2397                1     1      0.948581      1
# 2403                1     1      0.109321      0
# 2406                1     1      0.949581      1
# 2421                1     1      0.849147      1
#
# [486 rows x 4 columns]

# %% [markdown]
# ### Ausgabe des Tests als Kreuztabelle

# %%
crossTable = pd.crosstab(dataframeOfResult['Modell'],
                             dataframeOfResult['Real'],
                             margins= True, margins_name='Summe')    
crossTable
# Out:
# Real          0    1  Summe
# Modell
# 0           225   21    246
# 1            21  196    217
# unbestimmt   13   10     23
# Summe       259  227    486

# %% [markdown]
# ### Ausgabe des Netzstruktur als Grafik

# %%
vs = NetVisualizer()
dot = vs.DrawNet(net = model, listOfInput = listOfAttributes, listOfOutput = [classLabel], nodesep = 0.1, ranksep= 0.3, showWeights = False)
dot
